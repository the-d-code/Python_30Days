# %% [markdown]
# # 16-01-2023 | DAY 23 | END TO END PROJECT

# %%
# read data
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # linear algebra
import plotly.express as px
import plotly.graph_objects as go # or plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

df = pd.read_csv("NFLX.csv")
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-01-04    7.931429    7.961429    7.565714    7.640000    7.640000
# 1     2010-01-05    7.652857    7.657143    7.258571    7.358571    7.358571
# 2     2010-01-06    7.361429    7.672857    7.197143    7.617143    7.617143
# 3     2010-01-07    7.731429    7.757143    7.462857    7.485714    7.485714
# 4     2010-01-08    7.498571    7.742857    7.465714    7.614286    7.614286
# ...          ...         ...         ...         ...         ...         ...
# 3114  2022-05-17  189.169998  191.399994  185.169998  190.559998  190.559998
# 3115  2022-05-18  186.720001  187.699997  176.270004  177.190002  177.190002
# 3116  2022-05-19  178.050003  186.300003  175.710007  183.479996  183.479996
# 3117  2022-05-20  185.869995  190.190002  179.770004  186.350006  186.350006
# 3118  2022-05-23  186.149994  187.660004  177.889999  187.440002  187.440002
#
#         Volume
# 0     17239600
# ...

# %%
# top data
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  2010-01-04  7.931429  7.961429  7.565714  7.640000   7.640000  17239600
# 1  2010-01-05  7.652857  7.657143  7.258571  7.358571   7.358571  23753100
# 2  2010-01-06  7.361429  7.672857  7.197143  7.617143   7.617143  23290400
# 3  2010-01-07  7.731429  7.757143  7.462857  7.485714   7.485714   9955400
# 4  2010-01-08  7.498571  7.742857  7.465714  7.614286   7.614286   8180900

# %%
# bottom data
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 3114  2022-05-17  189.169998  191.399994  185.169998  190.559998  190.559998
# 3115  2022-05-18  186.720001  187.699997  176.270004  177.190002  177.190002
# 3116  2022-05-19  178.050003  186.300003  175.710007  183.479996  183.479996
# 3117  2022-05-20  185.869995  190.190002  179.770004  186.350006  186.350006
# 3118  2022-05-23  186.149994  187.660004  177.889999  187.440002  187.440002
#
#         Volume
# 3114   9876700
# 3115   9665600
# 3116  10448500
# 3117  10422600
# 3118   9558000

# %%
sns.set(rc={'figure.figsize':(10, 5)})

# %%
# change index

# correct date formate
df['Date'] = pd.to_datetime(df['Date'])
# set index
df = df.set_index('Date')
# sort index
df = df.sort_index()
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.931429    7.961429    7.565714    7.640000    7.640000
# 2010-01-05    7.652857    7.657143    7.258571    7.358571    7.358571
# 2010-01-06    7.361429    7.672857    7.197143    7.617143    7.617143
# 2010-01-07    7.731429    7.757143    7.462857    7.485714    7.485714
# 2010-01-08    7.498571    7.742857    7.465714    7.614286    7.614286
# ...                ...         ...         ...         ...         ...
# 2022-05-17  189.169998  191.399994  185.169998  190.559998  190.559998
# 2022-05-18  186.720001  187.699997  176.270004  177.190002  177.190002
# 2022-05-19  178.050003  186.300003  175.710007  183.479996  183.479996
# 2022-05-20  185.869995  190.190002  179.770004  186.350006  186.350006
# 2022-05-23  186.149994  187.660004  177.889999  187.440002  187.440002
#
#               Volume
# Date
# 2010-01-04  17239600
# 2010-01-05  23753100
# 2010-01-06  23290400
# ...

# %%
# volume of stock traded

sns.lineplot(x=df.index, y=df['Volume'])
plt.title("Volume of Stock Traded")
plt.show()

# %%
# volume of stock traded

sns.lineplot(x=df.index, y=df['Volume'], label="Volume", color='blue')
plt.title("Volume of Stock Traded")

plt.show()

# %%
# netflix stock price : high, open, low, close

sns.lineplot(x=df.index, y=df['High'], label="High")
sns.lineplot(x=df.index, y=df['Open'], label="Open")
sns.lineplot(x=df.index, y=df['Low'], label="Low")
sns.lineplot(x=df.index, y=df['Close'], label="Close")
plt.title("Stock Price")
plt.ylabel("Price")
plt.show()

# %%
# netflix stock price : Day, Month, Year wise chart

fig, (ax1, ax2, ax3) = plt.subplots(3,figsize=(15, 10))

df.groupby(df.index.day).mean().plot(y = 'Volume', ax=ax1,xlabel="Day", ylabel="Volume", title="Day wise Volume")
df.groupby(df.index.month).mean().plot(y = 'Volume', ax=ax2,xlabel="Month", ylabel="Volume", title="Month wise Volume")
df.groupby(df.index.year).mean().plot(y = 'Volume', ax=ax3,xlabel="Year", ylabel="Volume", title="Year wise Volume")

plt.show()

# %%
# top 5 dates with highest stock price

a = df.sort_values(by='High', ascending=False).head(5)
a['High']
# Out:
# Date
# 2021-11-17    700.989990
# 2021-11-19    694.159973
# 2021-11-18    691.739990
# 2021-10-29    690.969971
# 2021-11-01    689.969971
# Name: High, dtype: float64

# %%
# top 5 dates with lowest stock price

a = df.sort_values(by='Low', ascending=True).head(5)
a['Low']
# Out:
# Date
# 2010-01-25    6.931429
# 2010-01-26    6.937143
# 2010-01-27    6.992857
# 2010-01-06    7.197143
# 2010-01-21    7.214286
# Name: Low, dtype: float64

# %%
# plot graph

fig,axes = plt.subplots(nrows=1, ncols=2, sharex=True, figsize=(15, 5))
fig.suptitle('High and Low Stock Price per period of time', fontsize=16)

sns.lineplot(ax=axes[0], x=df.index, y=df['High'], label="High", color='green')
sns.lineplot(ax=axes[1], x=df.index, y=df['Low'], label="Low", color='red')

plt.show()
