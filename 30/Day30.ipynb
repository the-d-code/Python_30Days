# %% [markdown]
# # 17-01-2023 | DAY 29 | END TO END PROJECT - Customer ifetime value analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.templates.default = 'plotly_white'

# %%
# load the data
df = pd.read_csv('customer_acquisition_data.csv')
df
# Out:
#      customer_id           channel       cost  conversion_rate  revenue
# 0              1          referral   8.320327         0.123145     4199
# 1              2  paid advertising  30.450327         0.016341     3410
# 2              3   email marketing   5.246263         0.043822     3164
# 3              4      social media   9.546326         0.167592     1520
# 4              5          referral   8.320327         0.123145     2419
# ..           ...               ...        ...              ...      ...
# 795          796      social media   9.546326         0.167592     2813
# 796          797   email marketing   5.246263         0.043822     3439
# 797          798      social media   9.546326         0.167592     2101
# 798          799  paid advertising  30.450327         0.016341      813
# 799          800   email marketing   5.246263         0.043822     4820
#
# [800 rows x 5 columns]

# %%
# Make a visualization for the distribution of customer acquisition costs

# create a histogram
fig = px.histogram(df, 
                   x="cost",
                   nbins=20,
                     title='Customer Acquisition Cost',
                       
)
fig.show()

# %%
# Create a visualization for the revenue generated by the customers

# create a histogram
fig = px.histogram(df, 
                   x="revenue",
                   nbins=20,
                     title='Customer Revenue',
                       
)
fig.show()

# %%
# compare the cost of acquisition aross various channels and determine which ones are them most and least profitable

cost_bY_channel = df.groupby('channel').agg({'cost':'sum'}).reset_index()

fig = px.bar(cost_bY_channel,
                x='channel',
                y='cost',
                title='Customer Acquisition Cost by Channel',
                color='channel',
                color_discrete_sequence=px.colors.qualitative.Set1
                )
fig.show()

# %%
# find out which channels are most and least effetive at converting customers

conversions_by_channel = df.groupby('channel')['conversion_rate'].mean().reset_index()

fig = px.bar(conversions_by_channel,
                x='channel',
                y='conversion_rate',
                title='Conversion Rate by Channel',
                color='channel',
                color_discrete_sequence=px.colors.qualitative.Pastel
                )
fig.show()

# %%
# calculate the total revenuew by channel and analyze the most and least profitable channels n term of generating revenue

revenue_by_channel = df.groupby('channel')['revenue'].sum().reset_index()

fig = px.pie(revenue_by_channel,
                values='revenue',
                names='channel',
                title='Revenue by Channel',
                color_discrete_sequence=px.colors.qualitative.Pastel,
                hole=0.4
                
                )
fig.show()

# %%
# calculate the return on investment (ROI) for each channel

df['roi']= df['revenue']/df['cost']

roi_by_channel = df.groupby('channel')['roi'].mean().reset_index()

fig = px.bar(roi_by_channel,
                x='channel',
                y='roi',
                title='ROI by Channel',
                color='channel',
                color_discrete_sequence=px.colors.qualitative.Pastel
                )
fig.show()
