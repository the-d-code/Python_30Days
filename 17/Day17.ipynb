# %% [markdown]
# # 12-01-2023 | DAY 17 | Matplotlib Library Part - 2

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# change image color

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('img.png')
lum_img = img[:,:,0]
plt.imshow(lum_img)
plt.show()

# %%
# change image color

import numpy as np
import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
import matplotlib.image as Image

# %% [markdown]
# # PIE CHART

# %%
# PIE CHART

import matplotlib.pyplot as plt

X = [1,2,3]
Y = ["Part 1",2,3]
plt.pie(X, labels=Y)
plt.legend()
plt.show()
