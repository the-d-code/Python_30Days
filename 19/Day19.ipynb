# %% [markdown]
# # 12-01-2023 | DAY 19 | Seaborn Library Part - 2

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df1 = pd.read_csv('penguins.csv')
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]

# %% [markdown]
# # Bar plot in seaborn library

# %%
# bar plot
sns.barplot(x=df1.island, y=df1.bill_length_mm)
plt.show()

# %%
df1["island"]
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 344, dtype: object

# %%
sns.barplot(x="island", y="bill_length_mm", data=df1)
plt.show()

# %%
sns.barplot(x="island", y="bill_length_mm", data=df1, hue="sex")
plt.show()

# %%
order = [ "Dream","Torgersen", "Biscoe"]
sns.barplot(x = "island", y = "bill_length_mm", data = df1, order = order, hue = "sex")
plt.show()

# %% [markdown]
# # Hue order

# %%
# change the hue orderimport seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

df1 = pd.read_csv('penguins.csv')
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]

# %%
order = [ "Dream","Torgersen", "Biscoe"]
sns.barplot(x = "island", y = "bill_length_mm", data = df1, order = order, hue = "sex", hue_order=['FEMALE','MALE'])
plt.show()

# %%
order1 = [ "Dream","Torgersen", "Biscoe"]
sns.barplot(x ='island', y = 'bill_length_mm',data=df1,color="red")
plt.show()

# %%
order1 = [ "Dream","Torgersen", "Biscoe"]
sns.barplot(x ='island', y = 'bill_length_mm',data=df1,hue="sex", palette="Accent")
plt.show()

# %% [markdown]
# # Histogram Plot

# %%
# histogram plot
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]

# %%
sns.histplot(x="bill_length_mm", data=df1)
plt.show()

# %%
sns.displot(df1["flipper_length_mm"])
plt.show()
# Out:
# c:\Users\DevanshiAkbari\anaconda3\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # bins

# %%
sns.displot(df1["flipper_length_mm"], bins=[170, 180, 190, 200, 210, 220, 230, 240])
plt.show()
# Out:
# c:\Users\DevanshiAkbari\anaconda3\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # kde

# %%
sns.displot(df1["flipper_length_mm"], bins=[170, 180, 190, 200, 210, 220, 230, 240], kde=True, color="red")
plt.show()
# Out:
# c:\Users\DevanshiAkbari\anaconda3\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df1["flipper_length_mm"], bins=[170, 180, 190, 200, 210, 220, 230, 240], kde=False)
plt.show()
# Out:
# c:\Users\DevanshiAkbari\anaconda3\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
